# %% [markdown]
# ### 0. Import the packages

# %%
import os,sys,shutil,mmap
import pickle as pickle
import numpy as np                                       # fast vectors and matrices

import time

sys.path.insert(0,'lib/')
import config

from resampy import resample

from intervaltree import Interval, IntervalTree

# %% [markdown]
# ### 1. Resample the data
# Resample the recording and labels of the 331 recordings from the data base from 44100 Hz to 11025 Hz.
#
# #### 1.1 Resample the labels of the data set.
# The 331 resampled labels are saved in a dictionary whose
# - keys are integers (the ids of the recordings)
# - values are intervaltrees (for the different intervals of the recording it gives the played notes between 1 and 128)

# %%
def resample_label(file_in, file_out, frame_rate, frame_rate_out):
    ratio = frame_rate_out / float(frame_rate)
    print('.. resampling {} ({}Hz) into {} ({}Hz)'.format(
        file_in, frame_rate, file_out, frame_rate_out))
    print('.. sampling with ratio {}'.format(ratio))
    resampled_data = {}
    with open(file_in, 'rb') as f_in:
        labels = pickle.load(f_in)
        
        for key, value in labels.items() :
            resampled_intervals = []
            for interval in value:
                resampled_begin = int(interval.begin * ratio)
                resampled_end = int(interval.end * ratio)
                resampled_interval = Interval(
                    resampled_begin, resampled_end, interval.data)
                resampled_intervals.append(resampled_interval) 
            data = IntervalTree(resampled_intervals)
            resampled_data[key] = data   
            
        print('.. saving output')
        with open(file_out, 'wb') as f_out:
            pickle.dump(resampled_data, f_out)

# %%
resample_label(config.labels_path, config.labels_path_11, 44100, 11025)

with open(config.labels_path_11, 'rb') as f:
    labels = pickle.load(f)
# Out:
# .. resampling data/labels_mirex.pckl (44100Hz) into data/labels_mirex_11.pckl (11025Hz)
# .. sampling with ratio 0.25
# .. saving output

# %%
print(len(labels), 'labels')
# Out:
# 331 labels

# %%
for key, value in labels.items() :
    if key == 2239:
        # id of the recording
        print (key)
        # intervaltree containing for each note intervals in which it is played
        print (type(value))
# Out:
# 2239
# <class 'intervaltree.intervaltree.IntervalTree'>

# %% [markdown]
# #### 1.2 Resample recordings
#
# Create a dictionary containing the resampled data (recordings). Use Memory-mapped file objects.
# For each recording data[rec_id] is a tuple:
# 1. data[rec_id][0] is the memory-mapped file object to the recording. It can be accesed by
# ~~~~~~
# np.frombuffer(data[rec_id][0], dtype=np.float32).copy()
# ~~~~~~
# 2. data[rec_id][1] is its length (float)

# %%
sz_float = 4

# %%
def resample_music(file_in, file_out, frame_rate, frame_rate_out):
    ratio = frame_rate_out / float(frame_rate)
    print('.. resampling {} ({}Hz) into {} ({}Hz)'.format(
        file_in, frame_rate, file_out, frame_rate_out))
    print('.. sampling with ratio {}'.format(ratio))
 
    fd = os.open(file_in, os.O_RDONLY)
    buff = mmap.mmap(fd, 0, mmap.MAP_SHARED, mmap.PROT_READ)
    data_in = np.frombuffer(buff, dtype=np.float32).copy()
    
    data_out = resample(data_in, frame_rate, frame_rate_out)
    with open(file_out, 'wb') as f_out:
        np.save(f_out, data_out)
        
    os.close(fd)

# %%
data = dict()
for record in os.listdir(config.records_path):
    resample_music(config.records_path + record, config.records_path_11 + record, 44100, 11025)
    fd = os.open(config.records_path_11 + record, os.O_RDONLY)
    buff = mmap.mmap(fd, 0, mmap.MAP_SHARED, mmap.PROT_READ)
    data[int(record[:-4])] = (buff, len(buff)/sz_float)
    os.close(fd)
# Out:
# .. resampling data/records/2218.npy (44100Hz) into data/records_11/2218.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2512.npy (44100Hz) into data/records_11/2512.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2388.npy (44100Hz) into data/records_11/2388.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2678.npy (44100Hz) into data/records_11/2678.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2550.npy (44100Hz) into data/records_11/2550.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2213.npy (44100Hz) into data/records_11/2213.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1812.npy (44100Hz) into data/records_11/1812.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2405.npy (44100Hz) into data/records_11/2405.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1835.npy (44100Hz) into data/records_11/1835.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1729.npy (44100Hz) into data/records_11/1729.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2234.npy (44100Hz) into data/records_11/2234.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1933.npy (44100Hz) into data/records_11/1933.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2325.npy (44100Hz) into data/records_11/2325.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1822.npy (44100Hz) into data/records_11/1822.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2076.npy (44100Hz) into data/records_11/2076.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2505.npy (44100Hz) into data/records_11/2505.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1773.npy (44100Hz) into data/records_11/1773.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2186.npy (44100Hz) into data/records_11/2186.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2521.npy (44100Hz) into data/records_11/2521.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2203.npy (44100Hz) into data/records_11/2203.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2348.npy (44100Hz) into data/records_11/2348.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2391.npy (44100Hz) into data/records_11/2391.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2603.npy (44100Hz) into data/records_11/2603.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2208.npy (44100Hz) into data/records_11/2208.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2607.npy (44100Hz) into data/records_11/2607.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2376.npy (44100Hz) into data/records_11/2376.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2481.npy (44100Hz) into data/records_11/2481.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2527.npy (44100Hz) into data/records_11/2527.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2451.npy (44100Hz) into data/records_11/2451.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2081.npy (44100Hz) into data/records_11/2081.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2627.npy (44100Hz) into data/records_11/2627.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2224.npy (44100Hz) into data/records_11/2224.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1819.npy (44100Hz) into data/records_11/1819.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2082.npy (44100Hz) into data/records_11/2082.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2382.npy (44100Hz) into data/records_11/2382.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2590.npy (44100Hz) into data/records_11/2590.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2244.npy (44100Hz) into data/records_11/2244.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2416.npy (44100Hz) into data/records_11/2416.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2490.npy (44100Hz) into data/records_11/2490.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2504.npy (44100Hz) into data/records_11/2504.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2358.npy (44100Hz) into data/records_11/2358.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2492.npy (44100Hz) into data/records_11/2492.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2225.npy (44100Hz) into data/records_11/2225.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1756.npy (44100Hz) into data/records_11/1756.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2308.npy (44100Hz) into data/records_11/2308.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2195.npy (44100Hz) into data/records_11/2195.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2105.npy (44100Hz) into data/records_11/2105.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2079.npy (44100Hz) into data/records_11/2079.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2221.npy (44100Hz) into data/records_11/2221.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1872.npy (44100Hz) into data/records_11/1872.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2586.npy (44100Hz) into data/records_11/2586.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2289.npy (44100Hz) into data/records_11/2289.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1759.npy (44100Hz) into data/records_11/1759.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2632.npy (44100Hz) into data/records_11/2632.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2147.npy (44100Hz) into data/records_11/2147.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2611.npy (44100Hz) into data/records_11/2611.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2080.npy (44100Hz) into data/records_11/2080.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1775.npy (44100Hz) into data/records_11/1775.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2620.npy (44100Hz) into data/records_11/2620.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2320.npy (44100Hz) into data/records_11/2320.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2359.npy (44100Hz) into data/records_11/2359.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2161.npy (44100Hz) into data/records_11/2161.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2178.npy (44100Hz) into data/records_11/2178.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2243.npy (44100Hz) into data/records_11/2243.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2166.npy (44100Hz) into data/records_11/2166.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2241.npy (44100Hz) into data/records_11/2241.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2618.npy (44100Hz) into data/records_11/2618.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2404.npy (44100Hz) into data/records_11/2404.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2487.npy (44100Hz) into data/records_11/2487.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2628.npy (44100Hz) into data/records_11/2628.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1859.npy (44100Hz) into data/records_11/1859.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2282.npy (44100Hz) into data/records_11/2282.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2557.npy (44100Hz) into data/records_11/2557.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1805.npy (44100Hz) into data/records_11/1805.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2313.npy (44100Hz) into data/records_11/2313.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2537.npy (44100Hz) into data/records_11/2537.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2295.npy (44100Hz) into data/records_11/2295.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2366.npy (44100Hz) into data/records_11/2366.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2211.npy (44100Hz) into data/records_11/2211.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1772.npy (44100Hz) into data/records_11/1772.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2201.npy (44100Hz) into data/records_11/2201.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2334.npy (44100Hz) into data/records_11/2334.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2621.npy (44100Hz) into data/records_11/2621.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2424.npy (44100Hz) into data/records_11/2424.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2075.npy (44100Hz) into data/records_11/2075.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1873.npy (44100Hz) into data/records_11/1873.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1765.npy (44100Hz) into data/records_11/1765.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1919.npy (44100Hz) into data/records_11/1919.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2398.npy (44100Hz) into data/records_11/2398.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2516.npy (44100Hz) into data/records_11/2516.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2374.npy (44100Hz) into data/records_11/2374.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2169.npy (44100Hz) into data/records_11/2169.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2300.npy (44100Hz) into data/records_11/2300.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2582.npy (44100Hz) into data/records_11/2582.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2540.npy (44100Hz) into data/records_11/2540.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1764.npy (44100Hz) into data/records_11/1764.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2373.npy (44100Hz) into data/records_11/2373.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1876.npy (44100Hz) into data/records_11/1876.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1824.npy (44100Hz) into data/records_11/1824.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2335.npy (44100Hz) into data/records_11/2335.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2228.npy (44100Hz) into data/records_11/2228.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2622.npy (44100Hz) into data/records_11/2622.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2588.npy (44100Hz) into data/records_11/2588.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2106.npy (44100Hz) into data/records_11/2106.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1751.npy (44100Hz) into data/records_11/1751.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2403.npy (44100Hz) into data/records_11/2403.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2357.npy (44100Hz) into data/records_11/2357.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2180.npy (44100Hz) into data/records_11/2180.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2303.npy (44100Hz) into data/records_11/2303.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2436.npy (44100Hz) into data/records_11/2436.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2482.npy (44100Hz) into data/records_11/2482.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2294.npy (44100Hz) into data/records_11/2294.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2568.npy (44100Hz) into data/records_11/2568.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2343.npy (44100Hz) into data/records_11/2343.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2209.npy (44100Hz) into data/records_11/2209.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2576.npy (44100Hz) into data/records_11/2576.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2411.npy (44100Hz) into data/records_11/2411.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2570.npy (44100Hz) into data/records_11/2570.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2214.npy (44100Hz) into data/records_11/2214.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1766.npy (44100Hz) into data/records_11/1766.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2212.npy (44100Hz) into data/records_11/2212.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2345.npy (44100Hz) into data/records_11/2345.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1931.npy (44100Hz) into data/records_11/1931.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2297.npy (44100Hz) into data/records_11/2297.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2560.npy (44100Hz) into data/records_11/2560.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2156.npy (44100Hz) into data/records_11/2156.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2154.npy (44100Hz) into data/records_11/2154.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2247.npy (44100Hz) into data/records_11/2247.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2160.npy (44100Hz) into data/records_11/2160.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2336.npy (44100Hz) into data/records_11/2336.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2368.npy (44100Hz) into data/records_11/2368.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2365.npy (44100Hz) into data/records_11/2365.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1792.npy (44100Hz) into data/records_11/1792.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2138.npy (44100Hz) into data/records_11/2138.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2608.npy (44100Hz) into data/records_11/2608.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2633.npy (44100Hz) into data/records_11/2633.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1811.npy (44100Hz) into data/records_11/1811.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2285.npy (44100Hz) into data/records_11/2285.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2384.npy (44100Hz) into data/records_11/2384.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1918.npy (44100Hz) into data/records_11/1918.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2441.npy (44100Hz) into data/records_11/2441.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1727.npy (44100Hz) into data/records_11/1727.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2471.npy (44100Hz) into data/records_11/2471.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2486.npy (44100Hz) into data/records_11/2486.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2159.npy (44100Hz) into data/records_11/2159.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2531.npy (44100Hz) into data/records_11/2531.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1893.npy (44100Hz) into data/records_11/1893.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1789.npy (44100Hz) into data/records_11/1789.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2542.npy (44100Hz) into data/records_11/2542.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1923.npy (44100Hz) into data/records_11/1923.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2179.npy (44100Hz) into data/records_11/2179.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2310.npy (44100Hz) into data/records_11/2310.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2562.npy (44100Hz) into data/records_11/2562.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2194.npy (44100Hz) into data/records_11/2194.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2116.npy (44100Hz) into data/records_11/2116.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2564.npy (44100Hz) into data/records_11/2564.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2155.npy (44100Hz) into data/records_11/2155.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2230.npy (44100Hz) into data/records_11/2230.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2239.npy (44100Hz) into data/records_11/2239.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2595.npy (44100Hz) into data/records_11/2595.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1758.npy (44100Hz) into data/records_11/1758.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2423.npy (44100Hz) into data/records_11/2423.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2510.npy (44100Hz) into data/records_11/2510.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1790.npy (44100Hz) into data/records_11/1790.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2509.npy (44100Hz) into data/records_11/2509.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1757.npy (44100Hz) into data/records_11/1757.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2410.npy (44100Hz) into data/records_11/2410.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1922.npy (44100Hz) into data/records_11/1922.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2222.npy (44100Hz) into data/records_11/2222.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2443.npy (44100Hz) into data/records_11/2443.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2406.npy (44100Hz) into data/records_11/2406.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2372.npy (44100Hz) into data/records_11/2372.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2566.npy (44100Hz) into data/records_11/2566.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2215.npy (44100Hz) into data/records_11/2215.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2591.npy (44100Hz) into data/records_11/2591.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1752.npy (44100Hz) into data/records_11/1752.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1791.npy (44100Hz) into data/records_11/1791.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2118.npy (44100Hz) into data/records_11/2118.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2350.npy (44100Hz) into data/records_11/2350.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1777.npy (44100Hz) into data/records_11/1777.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2514.npy (44100Hz) into data/records_11/2514.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2389.npy (44100Hz) into data/records_11/2389.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2488.npy (44100Hz) into data/records_11/2488.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2614.npy (44100Hz) into data/records_11/2614.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2112.npy (44100Hz) into data/records_11/2112.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2315.npy (44100Hz) into data/records_11/2315.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2629.npy (44100Hz) into data/records_11/2629.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1813.npy (44100Hz) into data/records_11/1813.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2573.npy (44100Hz) into data/records_11/2573.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2220.npy (44100Hz) into data/records_11/2220.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2528.npy (44100Hz) into data/records_11/2528.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2305.npy (44100Hz) into data/records_11/2305.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2497.npy (44100Hz) into data/records_11/2497.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2298.npy (44100Hz) into data/records_11/2298.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2114.npy (44100Hz) into data/records_11/2114.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2202.npy (44100Hz) into data/records_11/2202.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2581.npy (44100Hz) into data/records_11/2581.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1749.npy (44100Hz) into data/records_11/1749.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2217.npy (44100Hz) into data/records_11/2217.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2150.npy (44100Hz) into data/records_11/2150.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2168.npy (44100Hz) into data/records_11/2168.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1788.npy (44100Hz) into data/records_11/1788.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1793.npy (44100Hz) into data/records_11/1793.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2304.npy (44100Hz) into data/records_11/2304.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2200.npy (44100Hz) into data/records_11/2200.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2523.npy (44100Hz) into data/records_11/2523.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1755.npy (44100Hz) into data/records_11/1755.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2507.npy (44100Hz) into data/records_11/2507.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1734.npy (44100Hz) into data/records_11/1734.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2307.npy (44100Hz) into data/records_11/2307.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2472.npy (44100Hz) into data/records_11/2472.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2149.npy (44100Hz) into data/records_11/2149.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2530.npy (44100Hz) into data/records_11/2530.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2117.npy (44100Hz) into data/records_11/2117.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2480.npy (44100Hz) into data/records_11/2480.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2227.npy (44100Hz) into data/records_11/2227.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2432.npy (44100Hz) into data/records_11/2432.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2371.npy (44100Hz) into data/records_11/2371.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2596.npy (44100Hz) into data/records_11/2596.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2284.npy (44100Hz) into data/records_11/2284.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1776.npy (44100Hz) into data/records_11/1776.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2593.npy (44100Hz) into data/records_11/2593.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2283.npy (44100Hz) into data/records_11/2283.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2383.npy (44100Hz) into data/records_11/2383.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2322.npy (44100Hz) into data/records_11/2322.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2341.npy (44100Hz) into data/records_11/2341.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2619.npy (44100Hz) into data/records_11/2619.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2501.npy (44100Hz) into data/records_11/2501.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2364.npy (44100Hz) into data/records_11/2364.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2293.npy (44100Hz) into data/records_11/2293.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2131.npy (44100Hz) into data/records_11/2131.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1916.npy (44100Hz) into data/records_11/1916.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2572.npy (44100Hz) into data/records_11/2572.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2083.npy (44100Hz) into data/records_11/2083.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2229.npy (44100Hz) into data/records_11/2229.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2491.npy (44100Hz) into data/records_11/2491.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2659.npy (44100Hz) into data/records_11/2659.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2104.npy (44100Hz) into data/records_11/2104.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2379.npy (44100Hz) into data/records_11/2379.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2242.npy (44100Hz) into data/records_11/2242.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2397.npy (44100Hz) into data/records_11/2397.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2677.npy (44100Hz) into data/records_11/2677.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2319.npy (44100Hz) into data/records_11/2319.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2433.npy (44100Hz) into data/records_11/2433.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2127.npy (44100Hz) into data/records_11/2127.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2415.npy (44100Hz) into data/records_11/2415.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2532.npy (44100Hz) into data/records_11/2532.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2478.npy (44100Hz) into data/records_11/2478.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2167.npy (44100Hz) into data/records_11/2167.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2240.npy (44100Hz) into data/records_11/2240.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2431.npy (44100Hz) into data/records_11/2431.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2207.npy (44100Hz) into data/records_11/2207.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2466.npy (44100Hz) into data/records_11/2466.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2567.npy (44100Hz) into data/records_11/2567.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1760.npy (44100Hz) into data/records_11/1760.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2463.npy (44100Hz) into data/records_11/2463.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2140.npy (44100Hz) into data/records_11/2140.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2494.npy (44100Hz) into data/records_11/2494.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2381.npy (44100Hz) into data/records_11/2381.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2232.npy (44100Hz) into data/records_11/2232.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2483.npy (44100Hz) into data/records_11/2483.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2555.npy (44100Hz) into data/records_11/2555.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2718.npy (44100Hz) into data/records_11/2718.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2346.npy (44100Hz) into data/records_11/2346.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2422.npy (44100Hz) into data/records_11/2422.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2219.npy (44100Hz) into data/records_11/2219.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2420.npy (44100Hz) into data/records_11/2420.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2113.npy (44100Hz) into data/records_11/2113.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1735.npy (44100Hz) into data/records_11/1735.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2442.npy (44100Hz) into data/records_11/2442.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2288.npy (44100Hz) into data/records_11/2288.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2533.npy (44100Hz) into data/records_11/2533.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2506.npy (44100Hz) into data/records_11/2506.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2191.npy (44100Hz) into data/records_11/2191.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2330.npy (44100Hz) into data/records_11/2330.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2157.npy (44100Hz) into data/records_11/2157.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2318.npy (44100Hz) into data/records_11/2318.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2148.npy (44100Hz) into data/records_11/2148.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2158.npy (44100Hz) into data/records_11/2158.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1750.npy (44100Hz) into data/records_11/1750.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1829.npy (44100Hz) into data/records_11/1829.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2177.npy (44100Hz) into data/records_11/2177.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1739.npy (44100Hz) into data/records_11/1739.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2393.npy (44100Hz) into data/records_11/2393.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2292.npy (44100Hz) into data/records_11/2292.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2476.npy (44100Hz) into data/records_11/2476.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1932.npy (44100Hz) into data/records_11/1932.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2529.npy (44100Hz) into data/records_11/2529.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2231.npy (44100Hz) into data/records_11/2231.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2196.npy (44100Hz) into data/records_11/2196.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2210.npy (44100Hz) into data/records_11/2210.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2248.npy (44100Hz) into data/records_11/2248.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2314.npy (44100Hz) into data/records_11/2314.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2575.npy (44100Hz) into data/records_11/2575.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2594.npy (44100Hz) into data/records_11/2594.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2502.npy (44100Hz) into data/records_11/2502.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2626.npy (44100Hz) into data/records_11/2626.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2522.npy (44100Hz) into data/records_11/2522.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2377.npy (44100Hz) into data/records_11/2377.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2417.npy (44100Hz) into data/records_11/2417.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1807.npy (44100Hz) into data/records_11/1807.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2390.npy (44100Hz) into data/records_11/2390.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2204.npy (44100Hz) into data/records_11/2204.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1728.npy (44100Hz) into data/records_11/1728.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1828.npy (44100Hz) into data/records_11/1828.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1730.npy (44100Hz) into data/records_11/1730.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2462.npy (44100Hz) into data/records_11/2462.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2556.npy (44100Hz) into data/records_11/2556.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2342.npy (44100Hz) into data/records_11/2342.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2392.npy (44100Hz) into data/records_11/2392.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2078.npy (44100Hz) into data/records_11/2078.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1768.npy (44100Hz) into data/records_11/1768.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1733.npy (44100Hz) into data/records_11/1733.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2477.npy (44100Hz) into data/records_11/2477.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1771.npy (44100Hz) into data/records_11/1771.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2473.npy (44100Hz) into data/records_11/2473.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2444.npy (44100Hz) into data/records_11/2444.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2538.npy (44100Hz) into data/records_11/2538.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2296.npy (44100Hz) into data/records_11/2296.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2571.npy (44100Hz) into data/records_11/2571.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1818.npy (44100Hz) into data/records_11/1818.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1817.npy (44100Hz) into data/records_11/1817.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2119.npy (44100Hz) into data/records_11/2119.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2077.npy (44100Hz) into data/records_11/2077.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1763.npy (44100Hz) into data/records_11/1763.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2198.npy (44100Hz) into data/records_11/2198.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2237.npy (44100Hz) into data/records_11/2237.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2151.npy (44100Hz) into data/records_11/2151.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2302.npy (44100Hz) into data/records_11/2302.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/1742.npy (44100Hz) into data/records_11/1742.npy (11025Hz)
# .. sampling with ratio 0.25
# .. resampling data/records/2238.npy (44100Hz) into data/records_11/2238.npy (11025Hz)
# .. sampling with ratio 0.25

# %%
for key, value in data.items() :
    if key == 2494:
        # id of the recording
        print ('Key:',key,', Format:',type(key))
        # its value is a tuple
        print ('Value:',value)
        # 1. value: reference to recording
        print ("1. Entry: Memory-mapped file objects ,", data[2494][0])
        # to access content use:
        x = np.frombuffer(data[2494][0], dtype=np.float32).copy()
        print('For example:')
        print(x[3005:3017])
        print ("2. Entry: length of recording",str(data[2494][1]),", Type:",type(data[2494][1]))
        #print(len(x))
# Out:
# Key: 2494 , Format: <class 'int'>
# Value: (<mmap.mmap object at 0x7f9671fe3300>, 3275168.0)
# 1. Entry: Memory-mapped file objects , <mmap.mmap object at 0x7f9671fe3300>
# For example:
# [-4.7592088e-08  1.7693633e-07 -3.0272071e-07  4.2005357e-07
#  -5.2369535e-07  6.0711841e-07 -6.6018526e-07 -6.9671851e-06
#  -5.5540130e-07  8.6105437e-08  5.2294681e-06  4.2070492e-06]
# 2. Entry: length of recording 3275168.0 , Type: <class 'float'>
